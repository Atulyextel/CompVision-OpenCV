# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
image = cv2.imread("C:\Users\Atul Kumar Singh\masteropencv\images\input.jpg")
histogram = cv2.calcHist([image],[2],None,[256],[0,256])
reval = image.ravel()
print "reval = ",reval
print "size of reval = ",reval.shape
print "size of image = ",image.shape
count =0
for x in reval:
    count= count +1
print "count = ",count
plt.hist(image.ravel(),10,[0,1000])
plt.show()

# Viewing Separate Color Channels
color = ('h', 's', 'v')
# We now separate the colors and plot each in the Histogram
for i, col in enumerate(color):
    histogram2 = cv2.calcHist([image], [i], None, [256], [0, 256])
    plt.plot(histogram2, color = col)
    plt.xlim([0,256])
    
plt.show()
# Out:
# reval =  [12 18 31 ..., 19 24 39]
# size of reval =  (3100050L,)
# size of image =  (830L, 1245L, 3L)
# count =  3100050
